# %% [markdown]
# <a href="https://colab.research.google.com/github/jong104b-kr/AIFFEL_quest_cr/blob/master/kiosk0102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 합치기
# 주문표 출력하기
# 주문 번호 코드로 출력
print('⟝' + '-' * 30 + '⟞')
print('|' + ' ' * 31 + '|')
print('|' + ' ' * 31 + '|')
print('|' + ' ' * 31 + '|')
print('|' + ' ' * 31 + '|')
print('상품명 : HOT 아메리카노')
print('총 주문 금액 : 1500원')
print('|' + ' ' * 31 + '|')
print('|' + ' ' * 31 + '|')
print('|' + ' ' * 31 + '|')
print('|' + ' ' * 31 + '|')
print('⟝' + '-' * 30 + '⟞')

# 문제 2-2. 주문 메서드
# 음료의 이름과 가격을 출력하세요.
def menu_select(self):
    print() # 줄 바꿈
    n = int(input("음료의 번호를 입력하세요 : "))  # 음료 번호 입력
    self.price_sum = self.price[n-1]  # 선택 음료의 가격
    print(self.menu[n-1],' : ',self.price[n-1], '원')  # 메뉴

# 메뉴판
class Kiosk:
    def __init__(self):
        # 문제 2-1의 답을 입력하세요.
        self.menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
        self.price = [2000, 3000, 3000, 2500, 2500, 3000]

    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i+1, self.menu[i], ' : ', self.price[i], '원')

    # 주문 메서드
    def menu_select(self):
        print()  # 줄 바꿈
        n = int(input("음료 번호를 입력하세요 : "))  # 음료 번호 입력
        self.price_sum = self.price[n-1] # 선택음료의 가격

        # 음료온도 물어보기
        t=0 # 기본값 입력
        while t != 1 and t != 2: # 1이나 2를 입력할 때까지 물어보기
          t = int(input("HOT음료는 1을, ICE음료는 2를 입력하세요 : "))
          if t == 1:
            self.temp = "HOT" # 온도 속성 생성
          elif t == 2:
            self.temp = "ICE"
          else :
            print("다시 입력하세요.\n")
        print('추가 주문 음료', self.temp, self.menu[n-1],' : ',self.price[n-1], '원') # 온도 속성을 추가한 주문 결과 출력
        # 문제 2-4. 추가 주문 또는 지불
        # 추가 주문 또는 지불
        n=0
        while n != 0:  # 지불을 선택하기 전까지 반복합니다.
            print()  # 줄 바꾸면서
            n = int(input("추가 주문은 음료 번호를, 지불은 0을 누르세요 : "))  # 추가 주문 또는 지불
            if n > 0 and n < len(self.menu) + 1:
                # 추가 음료 온도
                t = 0
                # 문제 2-4. 추가 음료의 온도를 입력받고, 가격 리스트, 주문 리스트, 합계 금액을 업데이트해보세요.
                while t!=1 and t!=2:
                  t = int(input("HOT음료는 1을, ICE음료는 2를 입력하세요 : "))
                  if t == 1:
                    self.temp = "HOT"
                  elif t == 2:
                    self.temp = "ICE"
                  else :
                    print("다시 입력하세요.\n")
                self.order_price.append(self.price[n-1]) # 가격 리스트에 추가
                self.order_menu.append(self.temp + ' ' + self.menu[n-1]) # 주문 리스트에 추가
                self.price_sum += self.price[n-1] # 합계금액

                print('추가 주문 음료', self.temp, self.menu[n-1], ':', self.price[n-1], '원\n', '합계 : ', self.price_sum, '원')
            else :
                if n == 0 :  # 지불을 입력하면
                    print("주문이 완료되었습니다.")
                    print(self.order_menu, self.order_price)  # 확인을 위한 리스트를 출력합니다.
                else :  # 없는 번호를 입력할 때
                    print("없는 메뉴입니다. 다시 주문해 주세요.")

    # 지불
    def pay(self):
      # 합계금액 출력
      print(f'총 합계 금액은 {self.price_sum}원 입니다.')
      # 지불방법
      self.pay_method = 0 # 기본값을 넣어주고
      while self.pay_method != 1 and self.pay_method != 2: # 1,2번을 입력하지 않으면 계속해서 반복
        self.pay_method = int(input('현금 결제는 1번, 카드 결제는 2번을 입력해주세요. : '))
        if self.pay_method == 1:
          print('직원을 호출하겠습니다.')
        elif self.pay_method == 2:
          print('IC칩 방향에 맞게 카드를 꽂아주세요.')
        else :
          print('다시 결제를 시도해 주세요.')
    # 주문표
    def table(self):
      # 외곽
      outline1 = "-"+"-"+30+"-"
      outline2 = "|" + " "*31+ "|"

      # 외곽 출력
      print(outline1)
      for i in range(5):
        print(outline2)

      # 주문상품명 : 해당금액
      for i in range(len(self.order_menu)):
        print(self.order_menu[i], ' : ',self.order_price[i])

      # 합계 금액
      print('합계 금액 :', self.price_sum)

      # 외곽 출력
      for i in range(5):
        print(outline2)
      print(outline1)

# 주문표 만들기
order = ['HOT americano', 'ICE latte', 'ICE mocha', 'ICE choco_latte']
price = [2000, 3000, 3000, 3000]

# 외곽
print('-'+'-'+30+'-')
for i in range(5):
  print('|' + ' '*31+ '|')

# 주문상품명
for i in range(len(order)) :
  print(order[i], ' : ', print[i])

print('합계금액 :', sum(price))

# 외곽
for i in range(5):
  print('|' + ' '*31+ '|')
print("-"+"-"+30+"-")
